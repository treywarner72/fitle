# %% [markdown]
# fitle is not a package anywhere so i just install it from github

# %%
# !pip3 install --no-deps --force-reinstall git+https://github.com/treywarner72/fitle.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/treywarner72/fitle.git
#   Cloning https://github.com/treywarner72/fitle.git to /tmp/pip-req-build-oj93q4x3
#   Running command git clone --filter=blob:none --quiet https://github.com/treywarner72/fitle.git /tmp/pip-req-build-oj93q4x3
#   Resolved https://github.com/treywarner72/fitle.git to commit 494db4402da878965a9470260d24490ea9b8a0eb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: fitle
#   Building wheel for fitle (pyproject.toml) ... done
#   Created wheel for fitle: filename=fitle-0.1.0-py3-none-any.whl size=24616 sha256=3969ff20bcee8eb12c1f22175ebd5212bc90c2130f1a6c2f5fcd3d3fe48391f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8nhwadam/wheels/35/2e/10/d871181ff3184108c182e5d56480edda1be6b0bda0f4f22fb7
# Successfully built fitle
# Installing collected packages: fitle
#   Attempting uninstall: fitle
#     Found existing installation: fitle 0.1.0
#     Uninstalling fitle-0.1.0:
#       Successfully uninstalled fitle-0.1.0
# Successfully installed fitle-0.1.0
